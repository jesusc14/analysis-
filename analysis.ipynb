# %%
# from google.transit import gtfs_realtime_pb2
import requests
import pandas as pd

# import protobuf
import gtfs_realtime_pb2
import datetime
from time import strftime, localtime
from protobuf_to_dict import protobuf_to_dict
from datetime import datetime
import math
from datetime import datetime


feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get(
    "https://s3.amazonaws.com/kcm-alerts-realtime-prod/tripupdates.pb"
)
feed.ParseFromString(response.content)
# Out:
# 277298

# %%
print("There are {} buses in the dataset.".format(len(feed.entity)))
# looking closely at the first bus


# def printRouteStatus():
#     num = 0
#     for entity in feed.entity:
#         if entity.HasField("vehicle"):
#             print(entity.vehicle.ccongestion_level)
#             num += 1
#     print(str(num) + ": how many buses")


# printRouteStatus()

bus = feed.entity[0]

bus

# for entity in feed.entity:
#     if entity.HasField("trip_update"):
#         print(
#             entity.trip_update.delay
#         )
# Out:
# There are 287 buses in the dataset.
# id: "1685200026_562565923"
# trip_update {
#   trip {
#     trip_id: "562565923"
#     route_id: "100001"
#     direction_id: 0
#     start_date: "20230527"
#   }
#   vehicle {
#     id: "4381"
#     label: "4381"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     stop_id: "3600"
#     arrival {
#       delay: 137
#       time: 1685199797
#     }
#     departure {
#       delay: 137
#       time: 1685199797
#     }
#   }
#   stop_time_update {
#     stop_sequence: 4
#     stop_id: "1500"
#     arrival {
#       delay: 137
#       time: 1685199874
#     }
#     departure {
#       delay: 137
#       time: 1685199874
#     }
#   }
#   stop_time_update {
#     stop_sequence: 9
#     stop_id: "1510"
#     arrival {
#       delay: 137
#       time: 1685199928
#     }
#     departure {
#       delay: 137
#       time: 1685199928
#     }
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "1530"
#     arrival {
#       delay: 137
#       time: 1685199977
#     }
#     departure {
#       delay: 137
#       time: 1685199977
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "1610"
#     arrival {
#       delay: 137
#       time: 1685200065
#     }
#     departure {
#       delay: 137
#       time: 1685200065
#     }
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "538"
#     arrival {
#       delay: 137
#       time: 1685200152
#     }
#     departure {
#       delay: 137
#       time: 1685200152
#     }
#   }
#   stop_time_update {
#     stop_sequence: 37
#     stop_id: "558"
#     arrival {
#       delay: 137
#       time: 1685200250
#     }
#     departure {
#       delay: 137
#       time: 1685200250
#     }
#   }
#   stop_time_update {
#     stop_sequence: 41
#     stop_id: "575"
#     arrival {
#       delay: 137
#       time: 1685200337
#     }
#     departure {
#       delay: 137
#       time: 1685200337
#     }
#   }
#   stop_time_update {
#     stop_sequence: 55
#     stop_id: "600"
#     arrival {
#       delay: 137
#       time: 1685200459
#     }
#     departure {
#       delay: 137
#       time: 1685200459
#     }
#   }
#   stop_time_update {
#     stop_sequence: 59
#     stop_id: "605"
#     arrival {
#       delay: 137
#       time: 1685200548
#     }
#     departure {
#       delay: 137
#       time: 1685200548
#     }
#   }
#   stop_time_update {
#     stop_sequence: 63
#     stop_id: "1690"
#     arrival {
#       delay: 137
#       time: 1685200625
#     }
#     departure {
#       delay: 137
#       time: 1685200625
#     }
#   }
#   stop_time_update {
#     stop_sequence: 71
#     stop_id: "2320"
#     arrival {
#       delay: 137
#       time: 1685200741
#     }
#     departure {
#       delay: 137
#       time: 1685200741
#     }
#   }
#   stop_time_update {
#     stop_sequence: 83
#     stop_id: "2330"
#     arrival {
#       delay: 137
#       time: 1685200817
#     }
#     departure {
#       delay: 137
#       time: 1685200817
#     }
#   }
#   stop_time_update {
#     stop_sequence: 90
#     stop_id: "2360"
#     arrival {
#       delay: 137
#       time: 1685200933
#     }
#     departure {
#       delay: 137
#       time: 1685200933
#     }
#   }
#   stop_time_update {
#     stop_sequence: 94
#     stop_id: "2370"
#     arrival {
#       delay: 137
#       time: 1685200997
#     }
#     departure {
#       delay: 137
#       time: 1685200997
#     }
#   }
#   stop_time_update {
#     stop_sequence: 101
#     stop_id: "2390"
#     arrival {
#       delay: 137
#       time: 1685201048
#     }
#     departure {
#       delay: 137
#       time: 1685201048
#     }
#   }
#   stop_time_update {
#     stop_sequence: 110
#     stop_id: "2400"
#     arrival {
#       delay: 137
#       time: 1685201075
#     }
#     departure {
#       delay: 137
#       time: 1685201075
#     }
#   }
#   stop_time_update {
#     stop_sequence: 112
#     stop_id: "2410"
#     arrival {
#       delay: 137
#       time: 1685201103
#     }
#     departure {
#       delay: 137
#       time: 1685201103
#     }
#   }
#   stop_time_update {
#     stop_sequence: 123
#     stop_id: "2420"
#     arrival {
#       delay: 137
#       time: 1685201143
#     }
#     departure {
#       delay: 137
#       time: 1685201143
#     }
#   }
#   stop_time_update {
#     stop_sequence: 142
#     stop_id: "2430"
#     arrival {
#       delay: 137
#       time: 1685201172
#     }
#     departure {
#       delay: 137
#       time: 1685201172
#     }
#   }
#   stop_time_update {
#     stop_sequence: 151
#     stop_id: "2440"
#     arrival {
#       delay: 137
#       time: 1685201214
#     }
#     departure {
#       delay: 137
#       time: 1685201214
#     }
#   }
#   stop_time_update {
#     stop_sequence: 161
#     stop_id: "2450"
#     arrival {
#       delay: 137
#       time: 1685201235
#     }
#     departure {
#       delay: 137
#       time: 1685201235
#     }
#   }
#   stop_time_update {
#     stop_sequence: 167
#     stop_id: "2460"
#     arrival {
#       delay: 137
#       time: 1685201275
#     }
#     departure {
#       delay: 137
#       time: 1685201275
#     }
#   }
#   stop_time_update {
#     stop_sequence: 169
#     stop_id: "2470"
#     arrival {
#       delay: 137
#       time: 1685201294
#     }
#     departure {
#       delay: 137
#       time: 1685201294
#     }
#   }
#   stop_time_update {
#     stop_sequence: 171
#     stop_id: "2480"
#     arrival {
#       delay: 137
#       time: 1685201323
#     }
#     departure {
#       delay: 137
#       time: 1685201323
#     }
#   }
#   stop_time_update {
#     stop_sequence: 178
#     stop_id: "2490"
#     arrival {
#       delay: 137
#       time: 1685201353
#     }
#     departure {
#       delay: 137
#       time: 1685201353
#     }
#   }
#   stop_time_update {
#     stop_sequence: 187
#     stop_id: "2500"
#     arrival {
#       delay: 137
#       time: 1685201392
#     }
#     departure {
#       delay: 137
#       time: 1685201392
#     }
#   }
#   stop_time_update {
#     stop_sequence: 202
#     stop_id: "2510"
#     arrival {
#       delay: 137
#       time: 1685201429
#     }
#     departure {
#       delay: 137
#       time: 1685201429
#     }
#   }
#   stop_time_update {
#     stop_sequence: 207
#     stop_id: "2520"
#     arrival {
#       delay: 137
#       time: 1685201452
#     }
#     departure {
#       delay: 137
#       time: 1685201452
#     }
#   }
#   stop_time_update {
#     stop_sequence: 228
#     stop_id: "2010"
#     arrival {
#       delay: 137
#       time: 1685201477
#     }
#     departure {
#       delay: 137
#       time: 1685201477
#     }
#   }
#   timestamp: 1685199999
# }

# %%
bus.trip_update.delay
# Out:
# 0

# %%
print(str(bus.vehicle.position.latitude) + ", " + str(bus.vehicle.position.longitude))
# print(bus.vehicle.position.latitude)

def findRouteName(str):
    print("hi")

findRouteName("hi")
# Out:
# 0.0, 0.0
# hi

# %%
# convert to dict from our original protobuf feed
buses_dict = protobuf_to_dict(feed)

# %%
df = pd.json_normalize(buses_dict['entity'])

# %%
df.head()
# print(df.size)
# Save the DataFrame to a CSV file
# df.to_csv('data.csv', index=False)
# Out:
#                      id trip_update.trip.trip_id trip_update.trip.start_date
# 0  1685200026_562565923                562565923                    20230527  \
# 1  1685200026_562566043                562566043                    20230527
# 2  1685200026_562561853                562561853                    20230527
# 3  1685200026_585708773                585708773                    20230527
# 4  1685200026_585709403                585709403                    20230527
#
#   trip_update.trip.route_id  trip_update.trip.direction_id
# 0                    100001                              0  \
# 1                    100001                              0
# 2                    100002                              1
# 3                    100003                              0
# 4                    100003                              1
#
#                         trip_update.stop_time_update trip_update.vehicle.id
# 0  [{'stop_sequence': 1, 'arrival': {'delay': 137...                   4381  \
# 1  [{'stop_sequence': 151, 'arrival': {'delay': 4...                   4350
# 2  [{'stop_sequence': 48, 'arrival': {'delay': 42...                   4385
# 3  [{'stop_sequence': 51, 'arrival': {'delay': 53...                   8137
# 4  [{'stop_sequence': 132, 'arrival': {'delay': 1...                   8149
#
#   trip_update.vehicle.label  trip_update.timestamp
# 0                      4381           1.685200e+09
# 1                      4350           1.685200e+09
# 2                      4385           1.685200e+09
# 3                      8137           1.685200e+09
# 4                      8149           1.685200e+09

# %%
df['trip_update.stop_time_update'].to_csv('stoptimeupdate.csv', index=False)

# i need to find what object is in this 


# column_object = df['trip_update.stop_time_update']
print(df['trip_update.timestamp'])

# print(type(column_object))
# print(column_object.dtype)

new_df = pd.DataFrame(columns=['trip_id', 'start_date', 'delay'])
# Out:
# 0      1.685200e+09
# 1      1.685200e+09
# 2      1.685200e+09
# 3      1.685200e+09
# 4      1.685200e+09
#            ...
# 282    1.685200e+09
# 283    1.685200e+09
# 284    1.685200e+09
# 285    1.685200e+09
# 286    1.685200e+09
# Name: trip_update.timestamp, Length: 287, dtype: float64

# %%
# stop_time_updates[5][8]
# print(df["trip_update.stop_time_update"].dtype)
# len(df["trip_update.stop_time_update"])

# print(len(df["trip_update.stop_time_update"][0]))

# for data in df["trip_update.stop_time_update"][0]:
#     print(data["arrival"]["delay"])
#     print(data)

# tracker = 0

# nested for loop to go through each row and to make sure that it iterates for however many stops there are
# first for loop goes through all the rows
# Iterate through each row in the DataFrame
# for index, row in df.iterrows():
#     stop_time_updates = row["trip_update.stop_time_update"]

#     # Iterate through each dictionary within the 'stop_time_updates' list
#     for dictionary in stop_time_updates:
#         arrival_dict = dictionary.get(
#             "arrival", {}
#         )  # Use dict.get() to handle missing 'arrival' key
#         delay = arrival_dict.get(
#             "delay", 0
#         )  # Use dict.get() to handle missing 'delay' key

#         # Perform actions for dictionaries with positive delay
#         if delay > 0:
#             print(dictionary)
#             tracker += 1

# print(tracker)
# print(df['trip_update.stop_time_update'].where)


# for ind in df.index:
#     print(df['trip_update.stop_time_update'][ind][tracker])
#     tracker += 1
#     if(tracker > 3):
#         tracker = 0


# print(df['trip_update.stop_time_update'])
# print(df['trip_update.trip.route_id'])
# tracker = 0
# formatted_date = date.strftime("%B %d, %Y")

for index, row in df.iterrows():
    stop_time_updates = row["trip_update.stop_time_update"]
    trip_id = row["trip_update.trip.trip_id"]
    start_date = row["trip_update.trip.start_date"]
    time_of_day = row["trip_update.timestamp"]

    date_string = start_date

    # Convert the date string to a datetime object
    # date = datetime.strptime(date_string, "%Y%m%d")

    # Format the datetime object as a human-readable string
    # formatted_date = date.strftime("%B %d, %Y")

    # Assuming time_of_day is the POSIX time or a NaN value
    if math.isnan(time_of_day):
        formatted_time = "Not available"
    else:
        # Convert POSIX time to a datetime object
        dt = datetime.fromtimestamp(float(time_of_day))

        # Format the datetime object as a string in a desired format
        formatted_time = dt.strftime("%H:%M:%S")

    # Iterate through each dictionary within the 'stop_time_updates' list
    for dictionary in stop_time_updates:
        arrival_dict = dictionary.get("arrival", {})
        delay = arrival_dict.get("delay", 0)

        # Perform actions for dictionaries with positive delay
        if delay:
            # tracker = delay
            print("trip ID:", trip_id)
            print("Dictionary:", delay)
            # print("Date: ", formatted_date)
            print("time: ", formatted_time)

    # print("tracker == " + str(tracker))
    tracker = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 80
#      78 # Perform actions for dictionaries with positive delay
#      79 if delay:
# ---> 80     if delay > tracker:
#      81         # tracker = delay
#      82         print("trip ID:", trip_id)
#      83         print("Dictionary:", delay)
#
# NameError: name 'tracker' is not defined

# %%
data_list = []


date_string = "May 26, 2023"

# print(date)

for index, row in df.iterrows():
    stop_time_updates = row["trip_update.stop_time_update"]
    trip_id = row["trip_update.trip.trip_id"]
    start_date = row["trip_update.trip.start_date"]
    time_stamp = row["trip_update.timestamp"]
    # stop_id = row["trip_update.stop_time_update.stop_sequence"]

    date = datetime.strptime(start_date, "%Y%m%d")
    formatted_date = date.strftime("%B %d, %Y")
    date_day = datetime.strptime(formatted_date, "%B %d, %Y")

    date_cleaned = date.strftime("%Y-%m-%d")
    day_of_week = date_day.strftime("%A")

    for dictionary in stop_time_updates:
        stop_time_dict = dictionary.get("stop_sequence", {})
        arrival_dict = dictionary.get("arrival", {})
        delay = arrival_dict.get("delay", 0)
        stop = stop_time_dict
        stop_id = dictionary.get("stop_id", {})
        # stop_sequence = arrival_dict.get('stop_sequence', 0)

        if delay:
            if delay > tracker:
                tracker = delay
            if not math.isnan(float(time_stamp)):
                datetime_obj = datetime.fromtimestamp(time_stamp)
                formatted_datetime = datetime_obj.strftime("%H:%M:%S")


            data_list.append({'trip_id': trip_id, 'start_date': formatted_date, 'delay': delay, 'day_of_week': day_of_week, 'time_stamp': formatted_datetime, 'stop_sequence': stop, 'stop_id': stop_id})

    tracker = 0



new_df = pd.DataFrame(data_list, columns=['trip_id', 'start_date', 'delay', 'day_of_week', "time_stamp", 'stop_sequence', 'stop_id'])

print(new_df)
