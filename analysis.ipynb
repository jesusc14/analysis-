# %%
# from google.transit import gtfs_realtime_pb2
import requests
import pandas as pd
# import protobuf
import gtfs_realtime_pb2
import datetime
from time import strftime, localtime
from protobuf_to_dict import protobuf_to_dict
from datetime import datetime
import math
from datetime import datetime


feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get(
    "https://s3.amazonaws.com/kcm-alerts-realtime-prod/tripupdates.pb"
)
feed.ParseFromString(response.content)
# Out:
# 342537

# %%
print("There are {} buses in the dataset.".format(len(feed.entity)))
# looking closely at the first bus


# def printRouteStatus():
#     num = 0
#     for entity in feed.entity:
#         if entity.HasField("vehicle"):
#             print(entity.vehicle.ccongestion_level)
#             num += 1
#     print(str(num) + ": how many buses")


# printRouteStatus()

bus = feed.entity[0]

bus

# for entity in feed.entity:
#     if entity.HasField("trip_update"):
#         print(
#             entity.trip_update.delay
#         )
# Out:
# There are 416 buses in the dataset.
# id: "1685160259_562519573"
# trip_update {
#   trip {
#     trip_id: "562519573"
#     route_id: "100001"
#     direction_id: 0
#     start_date: "20230526"
#     schedule_relationship: CANCELED
#   }
#   vehicle {
#   }
#   stop_time_update {
#     stop_sequence: 1
#     stop_id: "3600"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 4
#     stop_id: "1500"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 9
#     stop_id: "1510"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "1530"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "1610"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "538"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 37
#     stop_id: "558"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 41
#     stop_id: "575"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 55
#     stop_id: "600"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 59
#     stop_id: "605"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 63
#     stop_id: "1690"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 71
#     stop_id: "2320"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 83
#     stop_id: "2330"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 90
#     stop_id: "2360"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 94
#     stop_id: "2370"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 101
#     stop_id: "2390"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 110
#     stop_id: "2400"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 112
#     stop_id: "2410"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 123
#     stop_id: "2420"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 142
#     stop_id: "2430"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 151
#     stop_id: "2440"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 161
#     stop_id: "2450"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 167
#     stop_id: "2460"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 169
#     stop_id: "2470"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 171
#     stop_id: "2480"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 178
#     stop_id: "2490"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 187
#     stop_id: "2500"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 202
#     stop_id: "2510"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 207
#     stop_id: "2520"
#     schedule_relationship: SKIPPED
#   }
#   stop_time_update {
#     stop_sequence: 228
#     stop_id: "2010"
#     schedule_relationship: SKIPPED
#   }
# }

# %%
bus.trip_update.delay
# Out:
# 0

# %%
print(str(bus.vehicle.position.latitude) + ", " + str(bus.vehicle.position.longitude))
# print(bus.vehicle.position.latitude)

def findRouteName(str):
    print("hi")

findRouteName("hi")
# Out:
# 0.0, 0.0
# hi

# %%
# convert to dict from our original protobuf feed
buses_dict = protobuf_to_dict(feed)

# %%
df = pd.json_normalize(buses_dict['entity'])

# %%
df.head()
# print(df.size)
# Save the DataFrame to a CSV file
# df.to_csv('data.csv', index=False)
# Out:
#                      id trip_update.trip.trip_id trip_update.trip.start_date
# 0  1685160259_562519573                562519573                    20230526  \
# 1  1685160259_562519683                562519683                    20230526
# 2  1685160259_562519923                562519923                    20230526
# 3  1685160259_562520133                562520133                    20230526
# 4  1685160259_562520323                562520323                    20230526
#
#    trip_update.trip.schedule_relationship trip_update.trip.route_id
# 0                                     3.0                    100001  \
# 1                                     3.0                    100001
# 2                                     3.0                    100001
# 3                                     3.0                    100001
# 4                                     3.0                    100001
#
#    trip_update.trip.direction_id
# 0                              0  \
# 1                              1
# 2                              0
# 3                              1
# 4                              0
#
#                         trip_update.stop_time_update trip_update.vehicle.id
# 0  [{'stop_sequence': 1, 'stop_id': '3600', 'sche...                    NaN  \
# 1  [{'stop_sequence': 1, 'stop_id': '2010', 'sche...                    NaN
# 2  [{'stop_sequence': 1, 'stop_id': '3600', 'sche...                    NaN
# 3  [{'stop_sequence': 1, 'stop_id': '2010', 'sche...                    NaN
# 4  [{'stop_sequence': 1, 'stop_id': '3600', 'sche...                    NaN
#
#   trip_update.vehicle.label  trip_update.timestamp
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN

# %%
df['trip_update.stop_time_update'].to_csv('stoptimeupdate.csv', index=False)

# i need to find what object is in this 


# column_object = df['trip_update.stop_time_update']
print(df['trip_update.timestamp'])

# print(type(column_object))
# print(column_object.dtype)

new_df = pd.DataFrame(columns=['trip_id', 'start_date', 'delay'])
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 411             NaN
# 412    1.685160e+09
# 413    1.685160e+09
# 414             NaN
# 415             NaN
# Name: trip_update.timestamp, Length: 416, dtype: float64

# %%
# stop_time_updates[5][8]
# print(df["trip_update.stop_time_update"].dtype)
# len(df["trip_update.stop_time_update"])

# print(len(df["trip_update.stop_time_update"][0]))

# for data in df["trip_update.stop_time_update"][0]:
#     print(data["arrival"]["delay"])
#     print(data)

# tracker = 0

# nested for loop to go through each row and to make sure that it iterates for however many stops there are
# first for loop goes through all the rows
# Iterate through each row in the DataFrame
# for index, row in df.iterrows():
#     stop_time_updates = row["trip_update.stop_time_update"]

#     # Iterate through each dictionary within the 'stop_time_updates' list
#     for dictionary in stop_time_updates:
#         arrival_dict = dictionary.get(
#             "arrival", {}
#         )  # Use dict.get() to handle missing 'arrival' key
#         delay = arrival_dict.get(
#             "delay", 0
#         )  # Use dict.get() to handle missing 'delay' key

#         # Perform actions for dictionaries with positive delay
#         if delay > 0:
#             print(dictionary)
#             tracker += 1

# print(tracker)
# print(df['trip_update.stop_time_update'].where)


# for ind in df.index:
#     print(df['trip_update.stop_time_update'][ind][tracker])
#     tracker += 1
#     if(tracker > 3):
#         tracker = 0


# print(df['trip_update.stop_time_update'])
# print(df['trip_update.trip.route_id'])
# tracker = 0
# formatted_date = date.strftime("%B %d, %Y")

for index, row in df.iterrows():
    stop_time_updates = row["trip_update.stop_time_update"]
    trip_id = row["trip_update.trip.trip_id"]
    start_date = row["trip_update.trip.start_date"]
    time_of_day = row["trip_update.timestamp"]

    date_string = start_date

    # Convert the date string to a datetime object
    # date = datetime.strptime(date_string, "%Y%m%d")

    # Format the datetime object as a human-readable string
    formatted_date = date.strftime("%B %d, %Y")

    # Assuming time_of_day is the POSIX time or a NaN value
    if math.isnan(time_of_day):
        formatted_time = "Not available"
    else:
        # Convert POSIX time to a datetime object
        dt = datetime.fromtimestamp(float(time_of_day))

        # Format the datetime object as a string in a desired format
        formatted_time = dt.strftime("%H:%M:%S")

    # Iterate through each dictionary within the 'stop_time_updates' list
    for dictionary in stop_time_updates:
        arrival_dict = dictionary.get("arrival", {})
        delay = arrival_dict.get("delay", 0)

        # Perform actions for dictionaries with positive delay
        if delay:
            if delay > tracker:
                tracker = delay
                print("trip ID:", trip_id)
                print("Dictionary:", delay)
                print("Date: ", formatted_date)
                print("time: ", formatted_time)

    # print("tracker == " + str(tracker))
    tracker = 0
# Out:
# trip ID: 562520513
# Dictionary: 24
# Date:  May 26, 2023
# time:  21:03:29
# trip ID: 562520543
# Dictionary: 450
# Date:  May 26, 2023
# time:  21:03:34
# trip ID: 562527823
# Dictionary: 75
# Date:  May 26, 2023
# time:  21:03:38
# trip ID: 562527853
# Dictionary: 24
# Date:  May 26, 2023
# time:  21:03:27
# trip ID: 585761033
# Dictionary: 248
# Date:  May 26, 2023
# time:  21:03:40
# trip ID: 585762933
# Dictionary: 139
# Date:  May 26, 2023
# time:  21:03:31
# trip ID: 608975823
# Dictionary: 38
# Date:  May 26, 2023
# time:  21:00:05
# trip ID: 608975863
# Dictionary: 228
# Date:  May 26, 2023
# time:  21:03:42
# trip ID: 605293343
# Dictionary: 108
# Date:  May 26, 2023
# time:  21:03:33
# trip ID: 581464773
# Dictionary: 884
# Date:  May 26, 2023
# time:  21:03:27
# trip ID: 581464783
# Dictionary: 61
# Date:  May 26, 2023
# time:  21:03:24
# trip ID: 581465413
# Dictionary: 279
# Date:  May 26, 2023
# time:  21:00:19
# trip ID: 581465423
# Dictionary: 183
# Date:  May 26, 2023
# time:  21:03:33
# trip ID: 541149583
# Dictionary: 550
# Date:  May 26, 2023
# time:  21:03:26
# trip ID: 608972523
# Dictionary: 361
# Date:  May 26, 2023
# time:  21:03:42
# trip ID: 608972533
# Dictionary: 821
# Date:  May 26, 2023
# time:  21:03:41
# trip ID: 608972553
# Dictionary: 372
# Date:  May 26, 2023
# time:  21:03:42
# trip ID: 475810553
# Dictionary: 347
# Date:  May 26, 2023
# time:  21:03:30
# trip ID: 475811233
# Dictionary: 93
# Date:  May 26, 2023
# time:  21:03:35
# trip ID: 562329193
# Dictionary: 268
# Date:  May 26, 2023
# time:  21:03:35
# trip ID: 491922533
# Dictionary: 132
# Date:  May 26, 2023
# time:  21:03:36
# trip ID: 491923363
# Dictionary: 23
# Date:  May 26, 2023
# time:  21:03:25
# trip ID: 473767373
# Dictionary: 289
# Date:  May 26, 2023
# time:  21:00:40
# trip ID: 548848413
# Dictionary: 82
# Date:  May 26, 2023
# time:  21:03:42
# trip ID: 548848723
# Dictionary: 86
# Date:  May 26, 2023
# time:  21:03:27
# trip ID: 572953703
# Dictionary: 143
# Date:  May 26, 2023
# time:  21:03:24
# trip ID: 572954153
# Dictionary: 788
# Date:  May 26, 2023
# time:  21:03:37
# trip ID: 572954273
# Dictionary: 34
# Date:  May 26, 2023
# time:  21:03:31
# trip ID: 572954293
# Dictionary: 177
# Date:  May 26, 2023
# time:  21:03:39
# trip ID: 585990513
# Dictionary: 126
# Date:  May 26, 2023
# time:  21:03:33
# trip ID: 585990533
# Dictionary: 459
# Date:  May 26, 2023
# time:  21:03:32
# trip ID: 605111093
# Dictionary: 266
# Date:  May 26, 2023
# time:  21:03:26
# trip ID: 559797973
# Dictionary: 292
# Date:  May 26, 2023
# time:  21:03:41
# trip ID: 559802343
# Dictionary: 91
# Date:  May 26, 2023
# time:  21:03:24
# trip ID: 473763473
# Dictionary: 437
# Date:  May 26, 2023
# time:  21:02:54
# trip ID: 548842213
# Dictionary: 81
# Date:  May 26, 2023
# time:  21:03:24
# trip ID: 548842253
# Dictionary: 429
# Date:  May 26, 2023
# time:  21:03:33
# trip ID: 559797963
# Dictionary: 301
# Date:  May 26, 2023
# time:  21:03:33
# trip ID: 562520533
# Dictionary: 166
# Date:  May 26, 2023
# time:  21:03:40
# trip ID: 562520883
# Dictionary: 163
# Date:  May 26, 2023
# time:  21:03:40
# trip ID: 540552763
# Dictionary: 960
# Date:  May 26, 2023
# time:  21:00:27
# trip ID: 585760273
# Dictionary: 58
# Date:  May 26, 2023
# time:  21:03:29
# trip ID: 585761653
# Dictionary: 341
# Date:  May 26, 2023
# time:  21:03:42
# trip ID: 585762453
# Dictionary: 304
# Date:  May 26, 2023
# time:  21:03:37
# trip ID: 585760083
# Dictionary: 373
# Date:  May 26, 2023
# time:  21:03:34
# trip ID: 585768433
# Dictionary: 109
# Date:  May 26, 2023
# time:  21:03:42
# trip ID: 562319763
# Dictionary: 284
# Date:  May 26, 2023
# time:  21:03:28
# trip ID: 608968403
# Dictionary: 266
# Date:  May 26, 2023
# time:  21:03:31
# trip ID: 608968693
# Dictionary: 215
# Date:  May 26, 2023
# time:  21:00:21
# trip ID: 548774923
# Dictionary: 106
# Date:  May 26, 2023
# time:  21:03:34
# trip ID: 548775303
# Dictionary: 267
# Date:  May 26, 2023
# time:  21:03:39
# trip ID: 548782523
# Dictionary: 599
# Date:  May 26, 2023
# time:  21:03:41
# trip ID: 548782683
# Dictionary: 80
# Date:  May 26, 2023
# time:  21:03:41
# trip ID: 597697023
# Dictionary: 213
# Date:  May 26, 2023
# time:  21:03:34
# trip ID: 605082133
# Dictionary: 108
# Date:  May 26, 2023
# time:  21:03:23
# trip ID: 605082153
# Dictionary: 133
# Date:  May 26, 2023
# time:  21:03:36
# trip ID:
# Date:  May 26, 2023
# time:  21:03:33
# trip ID: 561369843
# Dictionary: 85
# Date:  May 26, 2023
# time:  21:03:26
# trip ID: 605443913
# Dictionary: 82
# Date:  May 26, 2023
# time:  21:03:23
# trip ID: 605443923
# Dictionary: 361
# Date:  May 26, 2023
# time:  21:03:34
# trip ID: 605443933
# Dictionary: 776
# Date:  May 26, 2023
# time:  21:03:29
# trip ID: 605444953
# Dictionary: 399
# Date:  May 26, 2023
# time:  21:03:39
# trip ID: 605444963
# Dictionary: 162
# Date:  May 26, 2023
# time:  21:03:34

# %%
data_list = []


date_string = "May 26, 2023"

print(date)

for index, row in df.iterrows():
    stop_time_updates = row["trip_update.stop_time_update"]
    trip_id = row["trip_update.trip.trip_id"]
    start_date = row["trip_update.trip.start_date"]
    time_stamp = row["trip_update.timestamp"]
    # stop_id = row["trip_update.stop_time_update.stop_sequence"]

    date = datetime.strptime(start_date, "%Y%m%d")
    formatted_date = date.strftime("%B %d, %Y")
    date_day = datetime.strptime(formatted_date, "%B %d, %Y")

    date_cleaned = date.strftime("%Y-%m-%d")
    day_of_week = date_day.strftime("%A")

    for dictionary in stop_time_updates:
        stop_time_dict = dictionary.get("stop_sequence", {})
        arrival_dict = dictionary.get("arrival", {})
        delay = arrival_dict.get("delay", 0)
        stop = stop_time_dict
        stop_id = dictionary.get("stop_id", {})
        # stop_sequence = arrival_dict.get('stop_sequence', 0)

        if delay:
            if delay > tracker:
                tracker = delay
            if not math.isnan(float(time_stamp)):
                datetime_obj = datetime.fromtimestamp(time_stamp)
                formatted_datetime = datetime_obj.strftime("%H:%M:%S")


            data_list.append({'trip_id': trip_id, 'start_date': formatted_date, 'delay': delay, 'day_of_week': day_of_week, 'time_stamp': formatted_datetime, 'stop_sequence': stop, 'stop_id': stop_id})

    tracker = 0



new_df = pd.DataFrame(data_list, columns=['trip_id', 'start_date', 'delay', 'day_of_week', "time_stamp", 'stop_sequence', 'stop_id'])

print(new_df)
# Out:
# 2023-05-26 00:00:00
#         trip_id    start_date  delay day_of_week time_stamp  stop_sequence
# 0     562520513  May 26, 2023     24      Friday   21:03:29             54  \
# 1     562520513  May 26, 2023     24      Friday   21:03:29             60
# 2     562520513  May 26, 2023     24      Friday   21:03:29             83
# 3     562520513  May 26, 2023     24      Friday   21:03:29             92
# 4     562520513  May 26, 2023     24      Friday   21:03:29             95
# ...         ...           ...    ...         ...        ...            ...
# 7185  605444963  May 26, 2023    162      Friday   21:03:34            407
# 7186  605444963  May 26, 2023    162      Friday   21:03:34            420
# 7187  605444963  May 26, 2023    162      Friday   21:03:34            425
# 7188  605444963  May 26, 2023    162      Friday   21:03:34            430
# 7189  605444963  May 26, 2023    162      Friday   21:03:34            441
#
#      stop_id
# 0       2100
# 1       2110
# 2       2120
# 3       2130
# 4       2140
# ...      ...
# 7185    1559
# 7186     548
# 7187     570
# 7188     590
# 7189     600
#
# [7190 rows x 7 columns]
